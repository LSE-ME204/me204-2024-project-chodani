# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Install Neccesary Packages and Check for HTML Request

# %%
#!pip install requests scrapy pandas

# %%
import requests                # for sending HTTP requests
from scrapy import Selector    # for parsing HTML content
import pandas as pd            # for creating dataframe

from pprint import pprint

# %%
url = "https://editorial.rottentomatoes.com/guide/best-movies-of-all-time/"
html = requests.get(url).content  # This sends a GET request to the URL and stores the HTML content

# %%
sel = Selector(text=html) # instantiate

# %% [markdown]
# import requests                # for sending HTTP requests
# from scrapy import Selector    # for parsing HTML content
# import pandas as pd

# %% [markdown]
# ## Create Functions to Gather Data from Website
# We will be collecting data from Rotten Tomatoes' top 300 movie list. We first gather the ranking list, and then we find the individual descriptions within each movie by going into their specific pages

# %%
# from the ranking page, collect movie hyperlink, movie titile, and movie rank
def get_movie_links(url):
    html = requests.get(url).content
    sel = Selector(text=html)

    movie_links =sel.css('span.details a::attr(href)').getall()
    movie_titles = sel.css('span.details a::text').getall()
    movie_ranks = sel.css('td:nth-child(1)::text').getall()

    return {'link': movie_links,
            'title': movie_titles,
            'rank': movie_ranks}

url = 'https://editorial.rottentomatoes.com/guide/best-movies-of-all-time/'

#pprint(get_movie_links(url))

# %%
# convert the gathered data into a dataframe
top_df = pd.DataFrame(get_movie_links(url))
top_df
# Out:
#                                                   link  \
# 0     https://www.rottentomatoes.com/m/la_confidential
# 1       https://www.rottentomatoes.com/m/the_godfather
# 2    https://www.rottentomatoes.com/m/1003707-casab...
# 3    https://www.rottentomatoes.com/m/seven_samurai...
# 4       https://www.rottentomatoes.com/m/parasite_2019
# ..                                                 ...
# 295  https://www.rottentomatoes.com/m/1001902-beaut...
# 296           https://www.rottentomatoes.com/m/killing
# 297  https://www.rottentomatoes.com/m/the_rules_of_...
# 298  https://www.rottentomatoes.com/m/eyes_without_...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
#
#                            title  rank
# 0              L.A. Confidential    1.
# 1                  The Godfather    2.
# 2                     Casablanca    3.
# 3                  Seven Samurai    4.
# 4                       Parasite    5.
# ..                           ...   ...
# 295         Beauty and the Beast  296.
# 296                  The Killing  297.
# 297        The Rules of the Game  298.
# 298          Eyes Without a Face  299.
# 299  The Cabinet of Dr. Caligari  300.
#
# [300 rows x 3 columns]

# %%
# go into each movie page and collect all information on it, from critic rating to box-office performance; if a piece of information is missing, fill it with none
def get_movie_info(url):
    html = requests.get(url).content
    sel = Selector(text=html)

    info_blocks = sel.css('div.content-wrap div.category-wrap')
    info_pairs = {}
    # there are some information which are hyperlinks and others that are pure text, so we have to operate on them differently
    links = ['Director', 'Producer', 'Screenwriter', 'Genre']
    texts = ['Distributor', 'Production Co', 'Rating', 'Original Language', 'Release Date (Theaters)', 'Release Date (Streaming)', 'Box Office (Gross USA)', 'Runtime', 'Sound Mix', 'Aspect Ratio']
    
    # collect description title and info from each text box
    for block in info_blocks:
        if block.css('dt.key rt-text::text').getall()[0] in links:
            info_pairs[f"{block.css('dt.key rt-text::text').getall()[0]}"] = block.css('dd rt-link::text').getall()
        elif block.css('dt.key rt-text::text').getall()[0] in texts:
            info_pairs[f"{block.css('dt.key rt-text::text').getall()[0]}"] = block.css('dd rt-text:not(rt-text.delimiter)::text').getall()
    
    # add rating scores
    info_pairs['critics_score'] = sel.css('rt-button:nth-child(3) > rt-text::text').getall()
    info_pairs['audience_score'] = sel.css('rt-button:nth-child(7) > rt-text::text').getall()

    # if a specific information was not represented on the webpage, change it to none for eventual dataframe
    for tag in links:
        if tag not in info_pairs.keys():
            info_pairs[tag] = None

    for tag in texts:
        if tag not in info_pairs.keys():
            info_pairs[tag] = None

    # reorder the columns to make them consistent for every movie page
    keys = list(info_pairs.keys())
    keys.sort()
    sorted_info_pairs = {i: info_pairs[i] for i in keys}

    return sorted_info_pairs

# test out the top movie page link (it has all datapoints filled)
get_movie_info('https://www.rottentomatoes.com/m/la_confidential')
# Out:
# {'Aspect Ratio': ['35mm', 'Scope (2.35:1)'],
#  'Box Office (Gross USA)': ['$64.6M'],
#  'Director': ['Curtis Hanson'],
#  'Distributor': ['Warner Home Vídeo', 'Warner Bros.'],
#  'Genre': ['Crime', 'Drama'],
#  'Original Language': ['English'],
#  'Producer': ['Michael G. Nathanson', 'Arnon Milchan', 'Curtis Hanson'],
#  'Production Co': ['Warner Brothers', 'Regency Enterprises'],
#  'Rating': ['R'],
#  'Release Date (Streaming)': ['Dec 12, 2015'],
#  'Release Date (Theaters)': ['Sep 19, 1997, Original'],
#  'Runtime': ['2h 16m'],
#  'Screenwriter': ['Curtis Hanson', 'James Ellroy', 'Brian Helgeland'],
#  'Sound Mix': ['Surround', 'DTS', 'Dolby Digital'],
#  'audience_score': ['94%'],
#  'critics_score': ['99%']}

# %%
# test out a movie link with some missing data, and we see it handles it alright
pprint(get_movie_info('https://www.rottentomatoes.com/m/saving_private_ryan'))
# Out:
# {'Aspect Ratio': ['Flat (1.85:1)'],
#  'Box Office (Gross USA)': None,
#  'Director': ['Steven Spielberg'],
#  'Distributor': ['Paramount Pictures', 'DreamWorks SKG'],
#  'Genre': ['War', 'History', 'Drama'],
#  'Original Language': ['English'],
#  'Producer': ['Ian Bryce', 'Mark Gordon', 'Gary Levinsohn', 'Steven Spielberg'],
#  'Production Co': ['DreamWorks SKG',
#                    'Mutual Film Company',
#                    'Amblin Entertainment',
#                    'Paramount Pictures',
#                    'Mark Gordon Productions'],
#  'Rating': ['R (Graphic Sequences of War|Graphic Sequences of '
#             'Violence|Language)'],
#  'Release Date (Streaming)': ['May 27, 2016'],
#  'Release Date (Theaters)': ['Jul 24, 1998, Wide'],
#  'Runtime': ['2h 49m'],
#  'Screenwriter': ['Robert Rodat'],
#  'Sound Mix': ['Dolby SR',
#                'DTS',
#                'Dolby Stereo',
#                'Surround',
#                'SDDS',
#                'Dolby A',
#                'Dolby Digital'],
#  'audience_score': ['95%'],
#  'critics_score': ['94%']}

# %%
# get movie info for all pages in the top 300 list
top_df['info'] = top_df['link'].apply(get_movie_info)
top_df
# Out:
#                                                   link  \
# 0     https://www.rottentomatoes.com/m/la_confidential
# 1       https://www.rottentomatoes.com/m/the_godfather
# 2    https://www.rottentomatoes.com/m/1003707-casab...
# 3    https://www.rottentomatoes.com/m/seven_samurai...
# 4       https://www.rottentomatoes.com/m/parasite_2019
# ..                                                 ...
# 295  https://www.rottentomatoes.com/m/1001902-beaut...
# 296           https://www.rottentomatoes.com/m/killing
# 297  https://www.rottentomatoes.com/m/the_rules_of_...
# 298  https://www.rottentomatoes.com/m/eyes_without_...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
#
#                            title  rank  \
# 0              L.A. Confidential    1.
# 1                  The Godfather    2.
# 2                     Casablanca    3.
# 3                  Seven Samurai    4.
# 4                       Parasite    5.
# ..                           ...   ...
# 295         Beauty and the Beast  296.
# 296                  The Killing  297.
# 297        The Rules of the Game  298.
# 298          Eyes Without a Face  299.
# 299  The Cabinet of Dr. Caligari  300.
#
#                                                   info
# 0    {'Aspect Ratio': ['35mm', 'Scope (2.35:1)'], '...
# 1    {'Aspect Ratio': ['Flat (1.85:1)'], 'Box Offic...
# 2    {'Aspect Ratio': ['Flat (1.37:1)'], 'Box Offic...
# 3    {'Aspect Ratio': ['Flat (1.37:1)'], 'Box Offic...
# 4    {'Aspect Ratio': ['Scope (2.35:1)'], 'Box Offi...
# ..                                                 ...
# 295  {'Aspect Ratio': ['Flat (1.37:1)'], 'Box Offic...
# 296  {'Aspect Ratio': None, 'Box Office (Gross USA)...
# 297  {'Aspect Ratio': ['35mm', 'Flat (1.37:1)'], 'B...
# 298  {'Aspect Ratio': None, 'Box Office (Gross USA)...
# 299  {'Aspect Ratio': None, 'Box Office (Gross USA)...
#
# [300 rows x 4 columns]

# %%
# expand the dataframe to seperate each information into individual columns
top_df = pd.concat([top_df.drop(['info'], axis=1), top_df['info'].apply(pd.Series)], axis=1)
top_df
# Out:
#                                                   link  \
# 0     https://www.rottentomatoes.com/m/la_confidential
# 1       https://www.rottentomatoes.com/m/the_godfather
# 2    https://www.rottentomatoes.com/m/1003707-casab...
# 3    https://www.rottentomatoes.com/m/seven_samurai...
# 4       https://www.rottentomatoes.com/m/parasite_2019
# ..                                                 ...
# 295  https://www.rottentomatoes.com/m/1001902-beaut...
# 296           https://www.rottentomatoes.com/m/killing
# 297  https://www.rottentomatoes.com/m/the_rules_of_...
# 298  https://www.rottentomatoes.com/m/eyes_without_...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
#
#                            title  rank            Aspect Ratio  \
# 0              L.A. Confidential    1.  m, Scope (2.35:1)]
# 1                  The Godfather    2.         [Flat (1.85:1)]
# 2                     Casablanca    3.         [Flat (1.37:1)]
# 3                  Seven Samurai    4.         [Flat (1.37:1)]
# 4                       Parasite    5.        [Scope (2.35:1)]
# ..                           ...   ...                     ...
# 295         Beauty and the Beast  296.         [Flat (1.37:1)]
# 296                  The Killing  297.                    None
# 297        The Rules of the Game  298.   m, Flat (1.37:1)]
# 298          Eyes Without a Face  299.                    None
# 299  The Cabinet of Dr. Caligari  300.                    None
#
#     Box Office (Gross USA)                Director  \
# 0                 [$64.6M]         [Curtis Hanson]
# 1                [$134.8M]  [Francis Ford Coppola]
# 2                     None        [Michael Curtiz]
# 3                [$192.9K]        [Akira Kurosawa]
# 4                 [$53.4M]          [Bong Joon Ho]
# ..                     ...                     ...
# 295              [$138.2K]          [Jean Cocteau]
# 296                   None       [Stanley Kubrick]
# 297                   None           [Jean Renoir]
# 298               [$52.7K]        [Georges Franju]
# 299                   None          [Robert Wiene]
#
#                                            Distributor  \
# 0                    [Warner Home Vídeo, Warner Bros.]
# 1                                 [Paramount Pictures]
# 2                              [Warner Bros. Pictures]
# 3                                  [Columbia Pictures]
# 4                                               [Neon]
# ..                                                 ...
# 295                                               None
# 296             [United Artists, Criterion Collection]
# 297              [Criterion Collection, Cine Classics]
# 298  [United Artists, Lopert Pictures Corp., Rialto...
# 299                      [Grapevine Video, Kino Video]
#
#                                      Genre  Original Language  \
# 0                           [Crime, Drama]          [English]
# 1                           [Crime, Drama]          [English]
# 2                                  [Drama]          [English]
# 3                                 [Action]         [Japanese]
# 4      [Comedy, Mystery & Thriller, Drama]           [Korean]
# ..                                     ...                ...
# 295                              [Fantasy]  [Canadian French]
# 296                         [Crime, Drama]          [English]
# 297                        [Comedy, Drama]  [French (France)]
# 298                        [Horror, Drama]  [Canadian French]
# 299  [Horror, Fantasy, Mystery & Thriller]           [German]
#
#                                               Producer  \
# 0    [Michael G. Nathanson, Arnon Milchan, Curtis H...
# 1                                    [Albert S. Ruddy]
# 2                                      [Hal B. Wallis]
# 3                                      [Sojiro Motoki]
# 4                         [Kwak Sin-ae, Moon Yanggwon]
# ..                                                 ...
# 295                                               None
# 296                                  [James B. Harris]
# 297                                    [Claude Renoir]
# 298                                     [Jules Borkon]
# 299                     [Rudolf Meinert, Erich Pommer]
#
#                                     Production Co  \
# 0          [Warner Brothers, Regency Enterprises]
# 1                            [Paramount Pictures]
# 2                               [Warner Brothers]
# 3                                  [Toho Company]
# 4                                  [Barunson E&A]
# ..                                            ...
# 295                                          None
# 296                  [Harris-Kubrick Productions]
# 297           [Nouvelles Éditions de Films (NEF)]
# 298  [Champs-Élysées Production, Lux Film S.p.a.]
# 299                            [Decla-Bioscop AG]
#
#                                           Rating Release Date (Streaming)  \
# 0                                            [R]           [Dec 12, 2015]
# 1                                            [R]            [Aug 1, 2013]
# 2                                           [PG]           [Aug 15, 2008]
# 3                                           None           [Nov 29, 2011]
# 4    [R (Sexual Content|Language|Some Violence)]           [Oct 11, 2019]
# ..                                           ...                      ...
# 295                                         None           [Jan 14, 2017]
# 296                                         None            [Mar 5, 2016]
# 297                                         None           [Jul 21, 2009]
# 298                                         None           [Oct 29, 2016]
# 299                                         None           [Mar 22, 2016]
#
#       Release Date (Theaters)   Runtime  \
# 0    [Sep 19, 1997, Original]  [2h 16m]
# 1        [Mar 15, 1972, Wide]  [2h 57m]
# 2        [Jan 23, 1943, Wide]  [1h 42m]
# 3        [Nov 19, 1956, Wide]  [3h 28m]
# 4         [Nov 1, 2019, Wide]  [2h 12m]
# ..                        ...       ...
# 295       [Jan 1, 1947, Wide]  [1h 35m]
# 296  [May 20, 1956, Original]  [1h 23m]
# 297   [Jul 8, 1939, Original]  [1h 50m]
# 298  [Oct 31, 1962, Original]  [1h 30m]
# 299      [Mar 19, 1921, Wide]   [1h 9m]
#
#                                           Screenwriter  \
# 0       [Curtis Hanson, James Ellroy, Brian Helgeland]
# 1       [Francis Ford Coppola, Mario Puzo, Mario Puzo]
# 2    [Murray Burnett, Joan Alison, Julius J. Epstei...
# 3     [Shinobu Hashimoto, Akira Kurosawa, Hideo Oguni]
# 4                           [Bong Joon Ho, Han Jinwon]
# ..                                                 ...
# 295  [Jean Cocteau, Jeanne-Marie Leprince de Beaumo...
# 296      [Stanley Kubrick, Jim Thompson, Lionel White]
# 297                           [Carl Koch, Jean Renoir]
# 298  [Pierre Boileau, Pierre Gascar, Thomas Narceja...
# 299                        [Hans Janowitz, Carl Mayer]
#
#                           Sound Mix audience_score critics_score
# 0    [Surround, DTS, Dolby Digital]          [94%]         [99%]
# 1                            [Mono]          [98%]         [97%]
# 2                            [Mono]          [95%]         [99%]
# 3                            [Mono]          [97%]        [100%]
# 4      [Dolby Atmos, Dolby Digital]          [90%]         [99%]
# ..                              ...            ...           ...
# 295                          [Mono]          [90%]         [96%]
# 296                            None          [92%]         [96%]
# 297                            None          [89%]         [97%]
# 298                            None          [87%]         [97%]
# 299                            None          [89%]         [96%]
#
# [300 rows x 19 columns]

# %%
# save raw data into dataframe for data cleaning
top_df.to_json('../data/raw/movies.json')
