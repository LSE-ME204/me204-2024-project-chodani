# %% [markdown]
# # Data Analysis and Visualizations

# %% [markdown]
# ## Import Packages and Read in Database as Pandas DataFrame
# We take the cleaned database and read it as a dataframe by merging our three tables together on the link variable. We also expand on columns which originally contained lists by seperating the strings by our delimiter "%%%".

# %%
import os
import sqlite3
import pandas as pd

# %%
DATA_FOLDER = os.path.join('../data/clean/')
conn = sqlite3.connect(os.path.join(DATA_FOLDER, 'moviedatabase.db'))

# %%
top_df = (
    pd.read_sql('SELECT * FROM movies', conn)
        .merge(pd.read_sql('SELECT * FROM technicalities', conn), 
                left_on='link', 
                right_on='link', 
                how='left')
        .merge(pd.read_sql('SELECT * FROM post_release', conn), 
                left_on='link', 
                right_on='link', 
                how='left')
)

# %%
def crypted_to_list(list_value):
    return list_value.split("%%%")[1:]

# %%
columns_to_convert = ['Aspect Ratio', 'Director', 'Distributor', 'Genre', 
                      'Producer', 'Production Co', 'Rating', 'Screenwriter', 'Sound Mix']
for column in columns_to_convert:
    top_df[column] = top_df[column].apply(lambda x: crypted_to_list(x) if isinstance(x, str) else [])

# %%
top_df.head()
# Out:
#                                                 link              title  \
# 0   https://www.rottentomatoes.com/m/la_confidential  L.A. Confidential
# 1     https://www.rottentomatoes.com/m/the_godfather      The Godfather
# 2  https://www.rottentomatoes.com/m/1003707-casab...         Casablanca
# 3  https://www.rottentomatoes.com/m/seven_samurai...      Seven Samurai
# 4     https://www.rottentomatoes.com/m/parasite_2019           Parasite
#
#                  Director                                Genre  language  \
# 0         [Curtis Hanson]                       [Crime, Drama]   English
# 1  [Francis Ford Coppola]                       [Crime, Drama]   English
# 2        [Michael Curtiz]                              [Drama]   English
# 3        [Akira Kurosawa]                             [Action]  Japanese
# 4          [Bong Joon Ho]  [Comedy, Mystery & Thriller, Drama]    Korean
#
#   date-streaming date-theater  Runtime  \
# 0   Dec 12, 2015   1997-09-19      136
# 1    Aug 1, 2013   1972-03-15      177
# 2   Aug 15, 2008   1943-01-23      102
# 3   Nov 29, 2011   1956-11-19      208
# 4   Oct 11, 2019   2019-11-01      132
#
#                                           Rating            Aspect Ratio  \
# 0                                            [R]  m, Scope (2.35:1)]
# 1                                            [R]         [Flat (1.85:1)]
# 2                                           [PG]         [Flat (1.37:1)]
# 3                                             []         [Flat (1.37:1)]
# 4  [R , Sexual Content, Language, Some Violence]        [Scope (2.35:1)]
#
#                          Distributor                       Sound Mix  \
# 0  [Warner Home Vídeo, Warner Bros.]  [Surround, DTS, Dolby Digital]
# 1               [Paramount Pictures]                          [Mono]
# 2            [Warner Bros. Pictures]                          [Mono]
# 3                [Columbia Pictures]                          [Mono]
# 4                             [Neon]    [Dolby Atmos, Dolby Digital]
#
#                                             Producer  \
# 0  [Michael G. Nathanson, Arnon Milchan, Curtis H...
# 1                                  [Albert S. Ruddy]
# 2                                    [Hal B. Wallis]
# 3                                    [Sojiro Motoki]
# 4                       [Kwak Sin-ae, Moon Yanggwon]
#
#                             Production Co  \
# 0  [Warner Brothers, Regency Enterprises]
# 1                    [Paramount Pictures]
# 2                       [Warner Brothers]
# 3                          [Toho Company]
# 4                          [Barunson E&A]
#
#                                         Screenwriter  rank      revenue  \
# 0     [Curtis Hanson, James Ellroy, Brian Helgeland]     1   64600000.0
# 1     [Francis Ford Coppola, Mario Puzo, Mario Puzo]     2  134800000.0
# 2  [Murray Burnett, Joan Alison, Julius J. Epstei...     3          NaN
# 3   [Shinobu Hashimoto, Akira Kurosawa, Hideo Oguni]     4     192900.0
# 4                         [Bong Joon Ho, Han Jinwon]     5   53400000.0
#
#    audience_score  critics_score
# 0              94             99
# 1              98             97
# 2              95             99
# 3              97            100
# 4              90             99

# %% [markdown]
# ## Early Data Analysis
# Play around and see any interesting trends or pieces of information

# %%
top_df.explode('Director')['Director'].value_counts()
# Out:
# Alfred Hitchcock    7
# Akira Kurosawa      6
# Billy Wilder        6
# Steven Spielberg    5
# Martin Scorsese     4
#                    ..
# Guy Hamilton        1
# George Lucas        1
# John Crowley        1
# Jon Watts           1
# Robert Wiene        1
# Name: Director, Length: 228, dtype: int64

# %%
top_df.explode('Screenwriter')['Screenwriter'].value_counts()
# Out:
# Andrew Stanton        8
# Pete Docter           6
# Akira Kurosawa        6
# Billy Wilder          6
# Charlie Chaplin       4
#                      ..
# Guillermo del Toro    1
# Robert Shaw           1
# Howard Sackler        1
# Carl Gottlieb         1
# Hans Janowitz         1
# Name: Screenwriter, Length: 528, dtype: int64

# %%
top_df.explode('Genre')['Genre'].value_counts()
# Out:
# Drama                 159
# Comedy                 88
# Adventure              61
# Mystery & Thriller     51
# Fantasy                41
# Action                 38
# Crime                  34
# Kids & Family          29
# Romance                27
# Animation              26
# History                22
# Sci-Fi                 22
# Horror                 15
# War                    13
# Biography              13
# Musical                10
# Western                 8
# Holiday                 5
# LGBTQ+                  5
# Music                   4
# Anime                   3
# Sports                  1
# Documentary             1
# Name: Genre, dtype: int64

# %%
top_df.explode('Genre').groupby('Genre')['revenue'].describe()
# Out:
#                     count          mean           std         min         25%  \
# Genre
# Action               30.0  2.423698e+08  2.400154e+08       123.0  59600000.0
# Adventure            46.0  2.341940e+08  2.153600e+08       123.0  33075000.0
# Animation            21.0  1.763364e+08  1.344414e+08    494000.0  48000000.0
# Anime                 0.0           NaN           NaN         NaN         NaN
# Biography            13.0  6.906105e+07  9.049391e+07      6400.0   7900000.0
# Comedy               57.0  1.067994e+08  1.534985e+08     17800.0   1800000.0
# Crime                17.0  5.930416e+07  5.686052e+07     29600.0   7600000.0
# Documentary           0.0           NaN           NaN         NaN         NaN
# Drama               100.0  4.728093e+07  6.308611e+07      6400.0    849700.0
# Fantasy              36.0  2.244223e+08  2.301167e+08       123.0   5050000.0
# History              19.0  7.225841e+07  8.806857e+07      6400.0    254950.0
# Holiday               5.0  8.588000e+07  1.087525e+08   3300000.0  20300000.0
# Horror                9.0  8.221697e+07  8.958108e+07     52700.0  13500000.0
# Kids & Family        23.0  1.636463e+08  1.349513e+08    494000.0  34850000.0
# LGBTQ+                4.0  1.341380e+07  1.449095e+07     55200.0   2863800.0
# Music                 4.0  5.677220e+07  1.026360e+08    188800.0   2447200.0
# Musical               7.0  8.105570e+07  1.096738e+08     18400.0    235750.0
# Mystery & Thriller   31.0  9.683454e+07  8.791349e+07     29600.0  20100000.0
# Romance              17.0  1.438445e+07  1.798356e+07     17800.0    162600.0
# Sci-Fi               18.0  1.759781e+08  2.128854e+08       123.0   9425000.0
# Sports                1.0  5.240000e+07           NaN  52400000.0  52400000.0
# War                   7.0  1.895926e+07  2.987135e+07     17800.0     40250.0
# Western               3.0  9.933333e+07  7.200231e+07  27000000.0  63500000.0
#
#                             50%          75%          max
# Genre
# Action              188650000.0  309225000.0  858400000.0
# Adventure           218750000.0  317600000.0  858400000.0
# Animation           206400000.0  245900000.0  434000000.0
# Anime                       NaN          NaN          NaN
# Biography            38900000.0   96900000.0  329700000.0
# Comedy               38400000.0  185500000.0  814100000.0
# Crime                42600000.0  124100000.0  164400000.0
# Documentary                 NaN          NaN          NaN
# Drama                20400000.0   62425000.0  329700000.0
# Fantasy             218200000.0  335925000.0  858400000.0
# History              52100000.0  126800000.0  329700000.0
# Holiday              47500000.0   86100000.0  272200000.0
# Horror               68400000.0   82600000.0  272200000.0
# Kids & Family       190200000.0  232450000.0  434000000.0
# LGBTQ+               10900000.0   21450000.0   31800000.0
# Music                 8200000.0   62525000.0  210500000.0
# Musical               5500000.0  156300000.0  248800000.0
# Mystery & Thriller   74300000.0  169500000.0  274100000.0
# Romance               4700000.0   34100000.0   44700000.0
# Sci-Fi               91550000.0  287450000.0  858400000.0
# Sports               52400000.0   52400000.0   52400000.0
# War                    516500.0   26650000.0   78800000.0
# Western             100000000.0  135500000.0  171000000.0

# %%
top_df['critics_score'].describe()
# Out:
# count    300.000000
# mean      96.546667
# std        2.306271
# min       89.000000
# 25%       95.000000
# 50%       97.000000
# 75%       98.000000
# max      100.000000
# Name: critics_score, dtype: float64

# %%
top_df['audience_score'].describe()
# Out:
# count    300.000000
# mean      91.066667
# std        3.711442
# min       79.000000
# 25%       89.000000
# 50%       92.000000
# 75%       94.000000
# max       99.000000
# Name: audience_score, dtype: float64

# %%
# critics score more homogenous...

# %%
# wht types of movies are long?
top_df['Runtime'].describe()
# Out:
# count    300.000000
# mean     117.700000
# std       27.236914
# min       60.000000
# 25%       97.750000
# 50%      113.000000
# 75%      131.000000
# max      250.000000
# Name: Runtime, dtype: float64

# %%
# For plotting purposes
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="27eh6V"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("27eh6V").appendChild(div);
#                     };
#                     var e = document.getElementById("27eh6V");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# This configures what shows up when you hover your mouse over the plot.
tooltip_setup = (
    layer_tooltips()
        .line('@category')
        .line('[@Q1 -- @median -- @Q3]')
        .format('@Q1', '£ {.2f}')
        .format('@median', '£ {.2f}')
        .format('@Q3', '£ {.2f}')
)

g = (
    # Maps the columns to the aesthetics of the plot.
    ggplot(plot_df, aes(y='category', x='median', xmin='Q1', xmax='Q3', fill='category')) +

    # GEOMS

    # Add a line range that 'listens to' columns informed in `ymin` and `ymax` aesthetics
    geom_linerange(size=1, alpha=0.75, tooltips=tooltip_setup) +

    # Add points to the plot (listen to `x` and `y` and fill aesthetics)
    geom_point(size=3, stroke=1, shape=21, tooltips=tooltip_setup) +

    # SCALES

    # Remove the legend (we can already read the categories from the y-axis)
    scale_fill_discrete(guide='none') +

    # Specify names for the axes
    scale_y_continuous(name="Discount Rate Categories\n(from smallest to largest rates)", expand=[0.05, 0.05]) +
    scale_x_log10(name="Price (£)", expand=[0., 0.05], format='£ {.2f}', breaks=np.arange(0, 20, 2.5)) +

    # LABELS
    labs(title='Products with lower prices tend to get bigger discounts',
         subtitle="The highest discounted products are the products with lower median prices.") +
    theme(axis_text_x=element_text(size=15),
        axis_text_y=element_text(size=17),
        axis_title_x=element_text(size=20),
        axis_title_y=element_text(size=20),
        plot_title=element_text(size=19, face='bold'),
        plot_subtitle=element_text(size=18),
        legend_position='none') +
    ggsize(1000, 500)

)

g
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 13
#       1 # This configures what shows up when you hover your mouse over the plot.
#       2 tooltip_setup = (
#       3     layer_tooltips()
#       4         .line('@category')
#    (...)
#       8         .format('@Q3', '£ {.2f}')
#       9 )
#      11 g = (
#      12     # Maps the columns to the aesthetics of the plot.
# ---> 13     ggplot(plot_df, aes(y='category', x='median', xmin='Q1', xmax='Q3', fill='category')) +
#      14
#      15     # GEOMS
#      16
#      17     # Add a line range that 'listens to' columns informed in `ymin` and `ymax` aesthetics
#      18     geom_linerange(size=1, alpha=0.75, tooltips=tooltip_setup) +
#      19
#      20     # Add points to the plot (listen to `x` and `y` and fill aesthetics)
#      21     geom_point(size=3, stroke=1, shape=21, tooltips=tooltip_setup) +
#      22
#      23     # SCALES
#      24
#      25     # Remove the legend (we can already read the categories from the y-axis)
#      26     scale_fill_discrete(guide='none') +
#      27
#      28     # Specify names for the axes
#      29     scale_y_continuous(name="Discount Rate Categories\n(from smallest to largest rates)", expand=[0.05, 0.05]) +
#      30     scale_x_log10(name="Price (£)", expand=[0., 0.05], format='£ {.2f}', breaks=np.arange(0, 20, 2.5)) +
#      31
#      32     # LABELS
#      33     labs(title='Products with lower prices tend to get bigger discounts',
#      34          subtitle="The highest discounted products are the products with lower median prices.") +
#      35     theme(axis_text_x=element_text(size=15),
#      36         axis_text_y=element_text(size=17),
#      37         axis_title_x=element_text(size=20),
#      38         axis_title_y=element_text(size=20),
#      39         plot_title=element_text(size=19, face='bold'),
#      40         plot_subtitle=element_text(size=18),
#      41         legend_position='none') +
#      42     ggsize(1000, 500)
#      43
#      44 )
#      46 g
#
# NameError: name 'plot_df' is not defined

# %%
scatter_plot = (
    ggplot(top_df, aes(x='audience_score', y='critics_score')) +
    geom_point() +
    scale_x_continuous(name='Audience Score', limits=[75, 100]) +
    scale_y_continuous(name='Critics Score', limits=[75, 100]) +
    labs(title='Scatter Plot of Audience vs Critics Score',
         x='Audience Score',
         y='Critics Score') +
    theme(
        axis_text_x=element_text(size=12),
        axis_text_y=element_text(size=12),
        axis_title_x=element_text(size=14),
        axis_title_y=element_text(size=14),
        plot_title=element_text(size=16, face='bold')
        
    ) + geom_jitter()
)

scatter_plot
# Out:
#    <div id="grCSuo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "audience_score":[94.0,98.0,95.0,97.0,90.0,97.0,99.0,87.0,93.0,95.0,95.0,92.0,95.0,95.0,91.0,94.0,96.0,90.0,93.0,93.0,94.0,93.0,86.0,95.0,97.0,90.0,94.0,94.0,97.0,94.0,86.0,92.0,90.0,92.0,95.0,92.0,89.0,94.0,90.0,95.0,92.0,95.0,94.0,88.0,97.0,89.0,95.0,95.0,88.0,93.0,94.0,91.0,93.0,95.0,94.0,94.0,94.0,90.0,86.0,95.0,94.0,96.0,94.0,94.0,95.0,88.0,87.0,92.0,93.0,94.0,88.0,89.0,93.0,86.0,93.0,89.0,92.0,94.0,93.0,94.0,94.0,97.0,89.0,95.0,94.0,90.0,91.0,90.0,89.0,90.0,94.0,93.0,87.0,95.0,82.0,92.0,92.0,89.0,94.0,87.0,84.0,90.0,89.0,90.0,93.0,91.0,91.0,91.0,96.0,97.0,92.0,79.0,91.0,88.0,94.0,89.0,87.0,95.0,87.0,91.0,90.0,95.0,96.0,89.0,90.0,87.0,94.0,98.0,93.0,93.0,91.0,94.0,87.0,93.0,89.0,96.0,92.0,79.0,97.0,93.0,87.0,90.0,95.0,93.0,91.0,89.0,92.0,94.0,90.0,91.0,95.0,93.0,93.0,90.0,87.0,90.0,96.0,92.0,96.0,96.0,95.0,86.0,95.0,92.0,87.0,92.0,88.0,89.0,93.0,94.0,92.0,82.0,93.0,92.0,92.0,86.0,91.0,94.0,94.0,94.0,90.0,83.0,85.0,86.0,80.0,88.0,92.0,91.0,89.0,93.0,92.0,85.0,86.0,86.0,89.0,92.0,90.0,92.0,91.0,88.0,95.0,98.0,92.0,93.0,86.0,90.0,89.0,98.0,86.0,89.0,85.0,83.0,85.0,93.0,90.0,93.0,92.0,89.0,92.0,93.0,94.0,87.0,94.0,93.0,79.0,89.0,95.0,90.0,86.0,94.0,88.0,87.0,93.0,86.0,95.0,94.0,86.0,93.0,79.0,89.0,91.0,90.0,92.0,96.0,90.0,90.0,90.0,87.0,91.0,90.0,95.0,94.0,89.0,92.0,89.0,88.0,92.0,92.0,88.0,96.0,88.0,97.0,87.0,86.0,92.0,88.0,88.0,87.0,87.0,93.0,89.0,85.0,85.0,87.0,89.0,87.0,88.0,84.0,93.0,95.0,93.0,92.0,93.0,93.0,91.0,91.0,91.0,90.0,92.0,91.0,82.0,93.0,93.0,87.0,90.0,90.0,92.0,89.0,87.0,89.0],
# "critics_score":[99.0,97.0,99.0,100.0,99.0,98.0,96.0,100.0,98.0,99.0,99.0,100.0,98.0,98.0,99.0,99.0,96.0,98.0,99.0,97.0,97.0,100.0,99.0,100.0,100.0,98.0,98.0,97.0,96.0,100.0,99.0,98.0,99.0,97.0,100.0,97.0,98.0,98.0,98.0,95.0,97.0,100.0,97.0,98.0,95.0,98.0,97.0,97.0,99.0,100.0,94.0,99.0,98.0,100.0,97.0,99.0,93.0,96.0,98.0,100.0,96.0,95.0,100.0,99.0,100.0,98.0,98.0,97.0,100.0,97.0,97.0,98.0,100.0,97.0,100.0,98.0,97.0,97.0,100.0,96.0,95.0,97.0,96.0,95.0,100.0,100.0,99.0,99.0,98.0,96.0,100.0,98.0,100.0,100.0,99.0,98.0,100.0,100.0,94.0,96.0,96.0,95.0,96.0,97.0,100.0,95.0,99.0,100.0,98.0,98.0,100.0,99.0,97.0,97.0,97.0,99.0,99.0,94.0,96.0,94.0,96.0,96.0,93.0,100.0,95.0,97.0,97.0,93.0,97.0,96.0,100.0,94.0,97.0,96.0,100.0,92.0,94.0,100.0,95.0,98.0,97.0,94.0,96.0,97.0,94.0,95.0,95.0,95.0,94.0,96.0,96.0,97.0,98.0,100.0,95.0,98.0,93.0,96.0,93.0,95.0,96.0,97.0,98.0,95.0,96.0,94.0,95.0,95.0,94.0,96.0,98.0,98.0,93.0,98.0,97.0,97.0,98.0,98.0,96.0,92.0,97.0,96.0,95.0,100.0,97.0,100.0,95.0,98.0,94.0,96.0,97.0,95.0,100.0,100.0,100.0,96.0,97.0,95.0,93.0,98.0,92.0,92.0,98.0,93.0,94.0,97.0,96.0,93.0,98.0,98.0,95.0,96.0,97.0,96.0,98.0,93.0,97.0,97.0,95.0,95.0,94.0,96.0,93.0,98.0,96.0,97.0,93.0,93.0,95.0,91.0,94.0,94.0,92.0,100.0,93.0,94.0,93.0,92.0,96.0,98.0,98.0,97.0,95.0,96.0,97.0,96.0,97.0,96.0,92.0,95.0,94.0,95.0,96.0,92.0,97.0,94.0,96.0,93.0,98.0,95.0,98.0,91.0,96.0,94.0,95.0,98.0,98.0,97.0,94.0,96.0,93.0,93.0,98.0,93.0,98.0,98.0,97.0,93.0,96.0,90.0,96.0,94.0,96.0,89.0,96.0,91.0,96.0,96.0,95.0,96.0,94.0,95.0,92.0,94.0,95.0,96.0,96.0,97.0,97.0,96.0]
# },
# "mapping":{
# "x":"audience_score",
# "y":"critics_score"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Scatter Plot of Audience vs Critics Score"
# },
# "theme":{
# "axis_title_x":{
# "size":14.0,
# "blank":false
# },
# "axis_title_y":{
# "size":14.0,
# "blank":false
# },
# "axis_text_x":{
# "size":12.0,
# "blank":false
# },
# "axis_text_y":{
# "size":12.0,
# "blank":false
# },
# "plot_title":{
# "face":"bold",
# "size":16.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[{
# "name":"Audience Score",
# "aesthetic":"x",
# "limits":[75.0,100.0]
# },{
# "name":"Critics Score",
# "aesthetic":"y",
# "limits":[75.0,100.0]
# },{
# "name":"Audience Score",
# "aesthetic":"x"
# },{
# "name":"Critics Score",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"jitter",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("grCSuo");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
