# %%
import os
import sqlite3
import pandas as pd

# %%
DATA_FOLDER = os.path.join('../data/clean/')
conn = sqlite3.connect(os.path.join(DATA_FOLDER, 'moviedatabase.db'))

# %%
top_df = (
    pd.read_sql('SELECT * FROM movies', conn)
        .merge(pd.read_sql('SELECT * FROM technicalities', conn), 
                left_on='link', 
                right_on='link', 
                how='left')
        .merge(pd.read_sql('SELECT * FROM post_release', conn), 
                left_on='link', 
                right_on='link', 
                how='left')
)

# %%
def crypted_to_list(list_value):
    return list_value.split("%%%")[1:]

# %%
columns_to_convert = ['Aspect Ratio', 'Director', 'Distributor', 'Genre', 
                      'Producer', 'Production Co', 'Rating', 'Screenwriter', 'Sound Mix']
for column in columns_to_convert:
    top_df[column] = top_df[column].apply(lambda x: crypted_to_list(x) if isinstance(x, str) else [])

# %%
top_df.head()
# Out:
#                                                 link              title  \
# 0   https://www.rottentomatoes.com/m/la_confidential  L.A. Confidential
# 1     https://www.rottentomatoes.com/m/the_godfather      The Godfather
# 2  https://www.rottentomatoes.com/m/1003707-casab...         Casablanca
# 3  https://www.rottentomatoes.com/m/seven_samurai...      Seven Samurai
# 4     https://www.rottentomatoes.com/m/parasite_2019           Parasite
#
#                  Director                                Genre  language  \
# 0         [Curtis Hanson]                       [Crime, Drama]   English
# 1  [Francis Ford Coppola]                       [Crime, Drama]   English
# 2        [Michael Curtiz]                              [Drama]   English
# 3        [Akira Kurosawa]                             [Action]  Japanese
# 4          [Bong Joon Ho]  [Comedy, Mystery & Thriller, Drama]    Korean
#
#   date-streaming date-theater  Runtime  \
# 0   Dec 12, 2015   1997-09-19      136
# 1    Aug 1, 2013   1972-03-15      177
# 2   Aug 15, 2008   1943-01-23      102
# 3   Nov 29, 2011   1956-11-19      208
# 4   Oct 11, 2019   2019-11-01      132
#
#                                           Rating            Aspect Ratio  \
# 0                                            [R]  m, Scope (2.35:1)]
# 1                                            [R]         [Flat (1.85:1)]
# 2                                           [PG]         [Flat (1.37:1)]
# 3                                             []         [Flat (1.37:1)]
# 4  [R , Sexual Content, Language, Some Violence]        [Scope (2.35:1)]
#
#                          Distributor                       Sound Mix  \
# 0  [Warner Home Vídeo, Warner Bros.]  [Surround, DTS, Dolby Digital]
# 1               [Paramount Pictures]                          [Mono]
# 2            [Warner Bros. Pictures]                          [Mono]
# 3                [Columbia Pictures]                          [Mono]
# 4                             [Neon]    [Dolby Atmos, Dolby Digital]
#
#                                             Producer  \
# 0  [Michael G. Nathanson, Arnon Milchan, Curtis H...
# 1                                  [Albert S. Ruddy]
# 2                                    [Hal B. Wallis]
# 3                                    [Sojiro Motoki]
# 4                       [Kwak Sin-ae, Moon Yanggwon]
#
#                             Production Co  \
# 0  [Warner Brothers, Regency Enterprises]
# 1                    [Paramount Pictures]
# 2                       [Warner Brothers]
# 3                          [Toho Company]
# 4                          [Barunson E&A]
#
#                                         Screenwriter rank      revenue  \
# 0     [Curtis Hanson, James Ellroy, Brian Helgeland]    1   64600000.0
# 1     [Francis Ford Coppola, Mario Puzo, Mario Puzo]    2  134800000.0
# 2  [Murray Burnett, Joan Alison, Julius J. Epstei...    3          NaN
# 3   [Shinobu Hashimoto, Akira Kurosawa, Hideo Oguni]    4     192900.0
# 4                         [Bong Joon Ho, Han Jinwon]    5   53400000.0
#
#    audience_score  critics_score
# 0            94.0           99.0
# 1            98.0           97.0
# 2            95.0           99.0
# 3            97.0          100.0
# 4            90.0           99.0

# %%
# For plotting purposes
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="m8krBr"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("m8krBr").appendChild(div);
#                     };
#                     var e = document.getElementById("m8krBr");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Group by 'category' and calculate statistics

summary_stats = top_df[top_df['revenue'].notna()].groupby('language')['revenue'].describe(percentiles=[.25, .5, .75])

# Create plot_df with required columns
plot_df = pd.DataFrame({
    'category': summary_stats.index,
    'count': summary_stats['count'],
    'mean': summary_stats['mean'],
    'std': summary_stats['std'],
    'min': summary_stats['min'],
    'Q1': summary_stats['25%'],
    'median': summary_stats['50%'],
    'Q3': summary_stats['75%'],
    'max': summary_stats['max']
})

# Ensure numeric columns are of appropriate type
numeric_cols = ['mean', 'std', 'min', 'Q1', 'median', 'Q3', 'max']
plot_df[numeric_cols] = plot_df[numeric_cols].astype(float)
plot_df = plot_df.sort_values(by='median')
# Print or return plot_df to verify
print(plot_df)
# Out:
#                                   category  count          mean           std  \
# language
# Arabic                              Arabic    1.0  5.590000e+04           NaN
# Canadian French            Canadian French    6.0  1.411833e+05  1.885353e+05
# French (France)            French (France)   10.0  5.994700e+05  1.161195e+06
# German                              German    3.0  4.501333e+05  6.510026e+05
# Russian                            Russian    2.0  1.547000e+05  1.466539e+05
# Japanese                          Japanese    5.0  2.185240e+06  4.370933e+06
# Italian                            Italian    4.0  3.526250e+05  3.314485e+05
# Swedish                            Swedish    1.0  2.100000e+06           NaN
# Australian English      Australian English    1.0  5.200000e+06           NaN
# Brazilian Portuguese  Brazilian Portuguese    1.0  7.600000e+06           NaN
# British English            British English    5.0  1.879004e+07  1.850267e+07
# Korean                              Korean    2.0  2.770000e+07  3.634529e+07
# European Spanish          European Spanish    1.0  3.760000e+07           NaN
# Chinese                            Chinese    1.0  5.360000e+07           NaN
# English                            English  141.0  1.211849e+08  1.566523e+08
#
#                              min          Q1      median           Q3  \
# language
# Arabic                   55900.0     55900.0     55900.0      55900.0
# Canadian French          17800.0     42725.0     67600.0     124275.0
# French (France)          18400.0     35700.0     94200.0     526075.0
# German                   29600.0     75200.0    120800.0     660400.0
# Russian                  51000.0    102850.0    154700.0     206550.0
# Japanese                 55200.0    192900.0    224100.0     454000.0
# Italian                  74300.0    153350.0    256300.0     455575.0
# Swedish                2100000.0   2100000.0   2100000.0    2100000.0
# Australian English     5200000.0   5200000.0   5200000.0    5200000.0
# Brazilian Portuguese   7600000.0   7600000.0   7600000.0    7600000.0
# British English         150200.0   3700000.0  13400000.0   38300000.0
# Korean                 2000000.0  14850000.0  27700000.0   40550000.0
# European Spanish      37600000.0  37600000.0  37600000.0   37600000.0
# Chinese               53600000.0  53600000.0  53600000.0   53600000.0
# English                    123.0  13500000.0  56700000.0  176000000.0
#
#                               max
# language
# Arabic                    55900.0
# Canadian French          516500.0
# French (France)         3800000.0
# German                  1200000.0
# Russian                  258400.0
# Japanese               10000000.0
# Italian                  823600.0
# Swedish                 2100000.0
# Australian English      5200000.0
# Brazilian Portuguese    7600000.0
# British English        38400000.0
# Korean                 53400000.0
# European Spanish       37600000.0
# Chinese                53600000.0
# English               858400000.0

# %%
# This configures what shows up when you hover your mouse over the plot.
tooltip_setup = (
    layer_tooltips()
        .line('@category')
        .line('[@Q1 -- @median -- @Q3]')
        .format('@Q1', '£ {.2f}')
        .format('@median', '£ {.2f}')
        .format('@Q3', '£ {.2f}')
)

g = (
    # Maps the columns to the aesthetics of the plot.
    ggplot(plot_df, aes(y='category', x='median', xmin='Q1', xmax='Q3', fill='category')) +

    # GEOMS

    # Add a line range that 'listens to' columns informed in `ymin` and `ymax` aesthetics
    geom_linerange(size=1, alpha=0.75, tooltips=tooltip_setup) +

    # Add points to the plot (listen to `x` and `y` and fill aesthetics)
    geom_point(size=3, stroke=1, shape=21, tooltips=tooltip_setup) +

    # SCALES

    # Remove the legend (we can already read the categories from the y-axis)
    scale_fill_discrete(guide='none') +

    # Specify names for the axes
    scale_y_continuous(name="Discount Rate Categories\n(from smallest to largest rates)", expand=[0.05, 0.05]) +
    scale_x_log10(name="Price (£)", expand=[0., 0.05], format='£ {.2f}', breaks=np.arange(0, 20, 2.5)) +

    # LABELS
    labs(title='Products with lower prices tend to get bigger discounts',
         subtitle="The highest discounted products are the products with lower median prices.") +
    theme(axis_text_x=element_text(size=15),
        axis_text_y=element_text(size=17),
        axis_title_x=element_text(size=20),
        axis_title_y=element_text(size=20),
        plot_title=element_text(size=19, face='bold'),
        plot_subtitle=element_text(size=18),
        legend_position='none') +
    ggsize(1000, 500)

)

g
# Out:
#    <div id="rJZbza"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "category":["Arabic","Canadian French","French (France)","German","Russian","Japanese","Italian","Swedish","Australian English","Brazilian Portuguese","British English","Korean","European Spanish","Chinese","English"],
# "Q1":[55900.0,42725.0,35700.0,75200.0,102850.0,192900.0,153350.0,2100000.0,5200000.0,7600000.0,3700000.0,1.485E7,3.76E7,5.36E7,1.35E7],
# "median":[55900.0,67600.0,94200.0,120800.0,154700.0,224100.0,256300.0,2100000.0,5200000.0,7600000.0,1.34E7,2.77E7,3.76E7,5.36E7,5.67E7],
# "Q3":[55900.0,124275.0,526075.0,660400.0,206549.99999999997,454000.0,455575.0,2100000.0,5200000.0,7600000.0,3.83E7,4.055E7,3.76E7,5.36E7,1.76E8]
# },
# "mapping":{
# "x":"median",
# "y":"category",
# "xmin":"Q1",
# "xmax":"Q3",
# "fill":"category"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Products with lower prices tend to get bigger discounts",
# "subtitle":"The highest discounted products are the products with lower median prices."
# },
# "theme":{
# "axis_title_x":{
# "size":20.0,
# "blank":false
# },
# "axis_title_y":{
# "size":20.0,
# "blank":false
# },
# "axis_text_x":{
# "size":15.0,
# "blank":false
# },
# "axis_text_y":{
# "size":17.0,
# "blank":false
# },
# "legend_position":"none",
# "plot_title":{
# "face":"bold",
# "size":19.0,
# "blank":false
# },
# "plot_subtitle":{
# "size":18.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "discrete":true
# },{
# "name":"Discount Rate Categories\n(from smallest to largest rates)",
# "aesthetic":"y",
# "expand":[0.05,0.05]
# },{
# "name":"Price (£)",
# "aesthetic":"x",
# "breaks":[0.0,2.5,5.0,7.5,10.0,12.5,15.0,17.5],
# "expand":[0.0,0.05],
# "trans":"log10",
# "format":"£ {.2f}"
# }],
# "layers":[{
# "geom":"linerange",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 -- @median -- @Q3]"]
# },
# "data_meta":{
# },
# "size":1.0,
# "alpha":0.75,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@Q1",
# "format":"£ {.2f}"
# },{
# "field":"@median",
# "format":"£ {.2f}"
# },{
# "field":"@Q3",
# "format":"£ {.2f}"
# }],
# "lines":["@category","[@Q1 -- @median -- @Q3]"]
# },
# "data_meta":{
# },
# "size":3.0,
# "stroke":1.0,
# "shape":21.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("rJZbza");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
scatter_plot = (
    ggplot(top_df, aes(x='audience_score', y='critics_score')) +
    geom_point() +
    scale_x_continuous(name='Audience Score', limits=[75, 100]) +
    scale_y_continuous(name='Critics Score', limits=[75, 100]) +
    labs(title='Scatter Plot of Audience vs Critics Score',
         x='Audience Score',
         y='Critics Score') +
    theme(
        axis_text_x=element_text(size=12),
        axis_text_y=element_text(size=12),
        axis_title_x=element_text(size=14),
        axis_title_y=element_text(size=14),
        plot_title=element_text(size=16, face='bold')
        
    ) + geom_jitter()
)

scatter_plot
# Out:
#    <div id="0xnFgl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "audience_score":[94.0,98.0,95.0,97.0,90.0,97.0,99.0,87.0,93.0,95.0,95.0,92.0,95.0,95.0,91.0,94.0,96.0,90.0,93.0,93.0,94.0,93.0,86.0,95.0,97.0,90.0,94.0,94.0,97.0,94.0,86.0,92.0,90.0,92.0,95.0,92.0,89.0,94.0,90.0,95.0,92.0,95.0,94.0,88.0,97.0,89.0,95.0,95.0,88.0,93.0,94.0,91.0,93.0,95.0,94.0,94.0,94.0,90.0,86.0,95.0,94.0,96.0,94.0,94.0,95.0,88.0,87.0,92.0,93.0,94.0,88.0,89.0,93.0,86.0,93.0,89.0,92.0,94.0,93.0,94.0,94.0,97.0,89.0,95.0,94.0,90.0,91.0,90.0,89.0,90.0,94.0,93.0,87.0,95.0,82.0,92.0,92.0,89.0,94.0,87.0,84.0,90.0,89.0,90.0,93.0,91.0,91.0,91.0,96.0,97.0,92.0,79.0,91.0,88.0,94.0,89.0,87.0,95.0,87.0,91.0,90.0,95.0,96.0,89.0,90.0,87.0,94.0,98.0,93.0,93.0,91.0,94.0,87.0,93.0,89.0,96.0,92.0,79.0,97.0,93.0,87.0,90.0,95.0,93.0,91.0,89.0,92.0,94.0,90.0,91.0,95.0,93.0,93.0,90.0,87.0,90.0,96.0,92.0,96.0,96.0,95.0,86.0,95.0,92.0,87.0,92.0,88.0,89.0,93.0,94.0,92.0,82.0,93.0,92.0,92.0,86.0,91.0,94.0,94.0,94.0,90.0,83.0,85.0,86.0,80.0,88.0,92.0,91.0,89.0,93.0,92.0,85.0,86.0,86.0,89.0,92.0,90.0,92.0,91.0,88.0,95.0,98.0,92.0,93.0,86.0,90.0,89.0,98.0,86.0,89.0,85.0,83.0,85.0,93.0,90.0,93.0,92.0,89.0,92.0,93.0,94.0,87.0,94.0,93.0,79.0,89.0,95.0,90.0,86.0,94.0,88.0,87.0,93.0,86.0,95.0,94.0,86.0,93.0,79.0,89.0,91.0,90.0,92.0,96.0,90.0,90.0,90.0,87.0,91.0,90.0,95.0,94.0,89.0,92.0,89.0,88.0,92.0,92.0,88.0,96.0,88.0,97.0,87.0,86.0,92.0,88.0,88.0,87.0,87.0,93.0,89.0,85.0,85.0,87.0,89.0,87.0,88.0,84.0,93.0,95.0,93.0,92.0,93.0,93.0,91.0,91.0,91.0,90.0,92.0,91.0,82.0,93.0,93.0,87.0,90.0,90.0,92.0,89.0,87.0,89.0],
# "critics_score":[99.0,97.0,99.0,100.0,99.0,98.0,96.0,100.0,98.0,99.0,99.0,100.0,98.0,98.0,99.0,99.0,96.0,98.0,99.0,97.0,97.0,100.0,99.0,100.0,100.0,98.0,98.0,97.0,96.0,100.0,99.0,98.0,99.0,97.0,100.0,97.0,98.0,98.0,98.0,95.0,97.0,100.0,97.0,98.0,95.0,98.0,97.0,97.0,99.0,100.0,94.0,99.0,98.0,100.0,97.0,99.0,93.0,96.0,98.0,100.0,96.0,95.0,100.0,99.0,100.0,98.0,98.0,97.0,100.0,97.0,97.0,98.0,100.0,97.0,100.0,98.0,97.0,97.0,100.0,96.0,95.0,97.0,96.0,95.0,100.0,100.0,99.0,99.0,98.0,96.0,100.0,98.0,100.0,100.0,99.0,98.0,100.0,100.0,94.0,96.0,96.0,95.0,96.0,97.0,100.0,95.0,99.0,100.0,98.0,98.0,100.0,99.0,97.0,97.0,97.0,99.0,99.0,94.0,96.0,94.0,96.0,96.0,93.0,100.0,95.0,97.0,97.0,93.0,97.0,96.0,100.0,94.0,97.0,96.0,100.0,92.0,94.0,100.0,95.0,98.0,97.0,94.0,96.0,97.0,94.0,95.0,95.0,95.0,94.0,96.0,96.0,97.0,98.0,100.0,95.0,98.0,93.0,96.0,93.0,95.0,96.0,97.0,98.0,95.0,96.0,94.0,95.0,95.0,94.0,96.0,98.0,98.0,93.0,98.0,97.0,97.0,98.0,98.0,96.0,92.0,97.0,96.0,95.0,100.0,97.0,100.0,95.0,98.0,94.0,96.0,97.0,95.0,100.0,100.0,100.0,96.0,97.0,95.0,93.0,98.0,92.0,92.0,98.0,93.0,94.0,97.0,96.0,93.0,98.0,98.0,95.0,96.0,97.0,96.0,98.0,93.0,97.0,97.0,95.0,95.0,94.0,96.0,93.0,98.0,96.0,97.0,93.0,93.0,95.0,91.0,94.0,94.0,92.0,100.0,93.0,94.0,93.0,92.0,96.0,98.0,98.0,97.0,95.0,96.0,97.0,96.0,97.0,96.0,92.0,95.0,94.0,95.0,96.0,92.0,97.0,94.0,96.0,93.0,98.0,95.0,98.0,91.0,96.0,94.0,95.0,98.0,98.0,97.0,94.0,96.0,93.0,93.0,98.0,93.0,98.0,98.0,97.0,93.0,96.0,90.0,96.0,94.0,96.0,89.0,96.0,91.0,96.0,96.0,95.0,96.0,94.0,95.0,92.0,94.0,95.0,96.0,96.0,97.0,97.0,96.0]
# },
# "mapping":{
# "x":"audience_score",
# "y":"critics_score"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Scatter Plot of Audience vs Critics Score"
# },
# "theme":{
# "axis_title_x":{
# "size":14.0,
# "blank":false
# },
# "axis_title_y":{
# "size":14.0,
# "blank":false
# },
# "axis_text_x":{
# "size":12.0,
# "blank":false
# },
# "axis_text_y":{
# "size":12.0,
# "blank":false
# },
# "plot_title":{
# "face":"bold",
# "size":16.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[{
# "name":"Audience Score",
# "aesthetic":"x",
# "limits":[75.0,100.0]
# },{
# "name":"Critics Score",
# "aesthetic":"y",
# "limits":[75.0,100.0]
# },{
# "name":"Audience Score",
# "aesthetic":"x"
# },{
# "name":"Critics Score",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"jitter",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0xnFgl");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
top_df.explode('Genre')
# Out:
#                                                   link  \
# 0     https://www.rottentomatoes.com/m/la_confidential
# 0     https://www.rottentomatoes.com/m/la_confidential
# 1       https://www.rottentomatoes.com/m/the_godfather
# 1       https://www.rottentomatoes.com/m/the_godfather
# 2    https://www.rottentomatoes.com/m/1003707-casab...
# ..                                                 ...
# 298  https://www.rottentomatoes.com/m/eyes_without_...
# 298  https://www.rottentomatoes.com/m/eyes_without_...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
# 299  https://www.rottentomatoes.com/m/the_cabinet_o...
#
#                            title                Director               Genre  \
# 0              L.A. Confidential         [Curtis Hanson]               Crime
# 0              L.A. Confidential         [Curtis Hanson]               Drama
# 1                  The Godfather  [Francis Ford Coppola]               Crime
# 1                  The Godfather  [Francis Ford Coppola]               Drama
# 2                     Casablanca        [Michael Curtiz]               Drama
# ..                           ...                     ...                 ...
# 298          Eyes Without a Face        [Georges Franju]              Horror
# 298          Eyes Without a Face        [Georges Franju]               Drama
# 299  The Cabinet of Dr. Caligari          [Robert Wiene]              Horror
# 299  The Cabinet of Dr. Caligari          [Robert Wiene]             Fantasy
# 299  The Cabinet of Dr. Caligari          [Robert Wiene]  Mystery & Thriller
#
#             language date-streaming date-theater  Runtime  Rating  \
# 0            English   Dec 12, 2015   1997-09-19      136     [R]
# 0            English   Dec 12, 2015   1997-09-19      136     [R]
# 1            English    Aug 1, 2013   1972-03-15      177     [R]
# 1            English    Aug 1, 2013   1972-03-15      177     [R]
# 2            English   Aug 15, 2008   1943-01-23      102  [P, G]
# ..               ...            ...          ...      ...     ...
# 298  Canadian French   Oct 29, 2016   1962-10-31       90      []
# 298  Canadian French   Oct 29, 2016   1962-10-31       90      []
# 299           German   Mar 22, 2016   1921-03-19       69      []
# 299           German   Mar 22, 2016   1921-03-19       69      []
# 299           German   Mar 22, 2016   1921-03-19       69      []
#
#                Aspect Ratio  \
# 0    m, Scope (2.35:1)]
# 0    m, Scope (2.35:1)]
# 1           [Flat (1.85:1)]
# 1           [Flat (1.85:1)]
# 2           [Flat (1.37:1)]
# ..                      ...
# 298                      []
# 298                      []
# 299                      []
# 299                      []
# 299                      []
#
#                                            Distributor  \
# 0                    [Warner Home Vídeo, Warner Bros.]
# 0                    [Warner Home Vídeo, Warner Bros.]
# 1                                 [Paramount Pictures]
# 1                                 [Paramount Pictures]
# 2                              [Warner Bros. Pictures]
# ..                                                 ...
# 298  [United Artists, Lopert Pictures Corp., Rialto...
# 298  [United Artists, Lopert Pictures Corp., Rialto...
# 299                      [Grapevine Video, Kino Video]
# 299                      [Grapevine Video, Kino Video]
# 299                      [Grapevine Video, Kino Video]
#
#                           Sound Mix  \
# 0    [Surround, DTS, Dolby Digital]
# 0    [Surround, DTS, Dolby Digital]
# 1                            [Mono]
# 1                            [Mono]
# 2                            [Mono]
# ..                              ...
# 298                              []
# 298                              []
# 299                              []
# 299                              []
# 299                              []
#
#                                               Producer  \
# 0    [Michael G. Nathanson, Arnon Milchan, Curtis H...
# 0    [Michael G. Nathanson, Arnon Milchan, Curtis H...
# 1                                    [Albert S. Ruddy]
# 1                                    [Albert S. Ruddy]
# 2                                      [Hal B. Wallis]
# ..                                                 ...
# 298                                     [Jules Borkon]
# 298                                     [Jules Borkon]
# 299                     [Rudolf Meinert, Erich Pommer]
# 299                     [Rudolf Meinert, Erich Pommer]
# 299                     [Rudolf Meinert, Erich Pommer]
#
#                                     Production Co  \
# 0          [Warner Brothers, Regency Enterprises]
# 0          [Warner Brothers, Regency Enterprises]
# 1                            [Paramount Pictures]
# 1                            [Paramount Pictures]
# 2                               [Warner Brothers]
# ..                                            ...
# 298  [Champs-Élysées Production, Lux Film S.p.a.]
# 298  [Champs-Élysées Production, Lux Film S.p.a.]
# 299                            [Decla-Bioscop AG]
# 299                            [Decla-Bioscop AG]
# 299                            [Decla-Bioscop AG]
#
#                                           Screenwriter rank      revenue  \
# 0       [Curtis Hanson, James Ellroy, Brian Helgeland]    1   64600000.0
# 0       [Curtis Hanson, James Ellroy, Brian Helgeland]    1   64600000.0
# 1       [Francis Ford Coppola, Mario Puzo, Mario Puzo]    2  134800000.0
# 1       [Francis Ford Coppola, Mario Puzo, Mario Puzo]    2  134800000.0
# 2    [Murray Burnett, Joan Alison, Julius J. Epstei...    3          NaN
# ..                                                 ...  ...          ...
# 298  [Pierre Boileau, Pierre Gascar, Thomas Narceja...  299      52700.0
# 298  [Pierre Boileau, Pierre Gascar, Thomas Narceja...  299      52700.0
# 299                        [Hans Janowitz, Carl Mayer]  300          NaN
# 299                        [Hans Janowitz, Carl Mayer]  300          NaN
# 299                        [Hans Janowitz, Carl Mayer]  300          NaN
#
#      audience_score  critics_score
# 0              94.0           99.0
# 0              94.0           99.0
# 1              98.0           97.0
# 1              98.0           97.0
# 2              95.0           99.0
# ..              ...            ...
# 298            87.0           97.0
# 298            87.0           97.0
# 299            89.0           96.0
# 299            89.0           96.0
# 299            89.0           96.0
#
# [676 rows x 19 columns]
